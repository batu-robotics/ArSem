# %% [markdown]
# # Çoklu Doğrusal Regresyon

# %% [markdown]
# ## 1. Kütüphanelerin Çağrılması

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
#from sklearn import * #Bu şekilde bütün elemanları çağırabiliriz
from sklearn.metrics import r2_score

# %% [markdown]
# ## 2. Dosyayı Çağırma

# %%
veri=pd.read_csv('cars.csv')
print(type(veri),'\n')
print(veri.head(15),'\n')
print(veri.tail(10))

# %% [markdown]
# ## 3. Verinin Bağımlı-Bağımsız Değişkenlerinin Belirlenmesi

# %%
x=veri.iloc[:,2:-1]
y=veri.iloc[:,-1]
print(x)

# %% [markdown]
# ## Regresyon Modelinin Oluşturulması

# %%
cok_reg=linear_model.LinearRegression()
cok_reg.fit(x,y)

print('Katsayılar= {}'.format(cok_reg.coef_))
print('Ofset= {}'.format(cok_reg.intercept_))
# Out:
# Katsayılar= [0.00780526 0.00755095]
# Ofset= 79.69471929115939

# %% [markdown]
# ## 4. Veri Girdi İlinti Analizi

# %%
sns.heatmap(x.corr(),annot=True)

# %%
sns.pairplot(x)

# %% [markdown]
# # Polinom Regresyonu

# %%
import numpy as np
from numpy.random import random,seed
from sklearn.metrics import r2_score

# %% [markdown]
# ## 1. Fonksiyon oluşturulması

# %%
seed()
x=random(50)
x=np.sort(x)
print(x)
noise1=random(50)
noise2=random(50)

y=(1-noise1)*100*x+40*noise2
print(y)

# %% [markdown]
# ## 2. Grafiğe Aktarım

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Verinin Grafiğe Aktarımı
fig='Grafik-1'
plt.figure(fig)
plt.plot(x,y,'*r')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.title('Polyfit')

# Polinom Regresyonu
pol_reg=np.poly1d(np.polyfit(x,y,18))
print(np.polyfit(x,y,18))
plt.plot(x,pol_reg(x),'-b')
plt.legend(['Orijinal Veri','Fit Eğrisi'])

# r2 skoru
print('r2 skoru= {:.2f}'.format(r2_score(y,pol_reg(x))))
# Out:
# [-2.83708155e+11  2.63343092e+12 -1.12850653e+13  2.96091065e+13
#  -5.31863631e+13  6.92878320e+13 -6.76532077e+13  5.04620955e+13
#  -2.90420313e+13  1.29382749e+13 -4.45052708e+12  1.17243451e+12
#  -2.33161527e+11  3.42364291e+10 -3.59152812e+09  2.56204751e+08
#  -1.15022988e+07  2.84034244e+05 -2.81665547e+03]
# r2 skoru= 0.58
